# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import os, sys
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Pointers

# %%
notebook_dir = Path(os.getcwd())
data_dir = notebook_dir.parent/'data'
output_dir = notebook_dir.parent/'output'

code_dir = notebook_dir.parent/'code'
sys.path.append(str(code_dir))

# %%
from HgDietSimulator import *

# %%
coastalwosm_required_percentages
# Out:
# {'Animal Products': 0.0003,
#  'Non-Salmon': 0.0707,
#  'Game': 0.0262,
#  'Moose and Caribou': 0.2105,
#  'Marine Mammal': 0.0279,
#  'Sugared Drinks': 0.16,
#  'Store Fruit and Fruit Juice': 0.07,
#  'Dairy and Eggs': 0.08,
#  'Grains': 0.12,
#  'Imported Protein': 0.07,
#  'Vegetable Fats': 0.07,
#  'Mixed Dishes': 0.05,
#  'Sweeteners and Candy': 0.03}

# %%
proteinscenario(store_file_name=output_dir/'coastal protein 100.pkl', region='Coastal')
# Out:
# Generating Coastal with Salmon diet 1 for Normal conditions ...
# Generating Coastal with Salmon diet 2 for Normal conditions ...
# Generating Coastal with Salmon diet 3 for Normal conditions ...
# Generating Coastal with Salmon diet 4 for Normal conditions ...
# Generating Coastal with Salmon diet 5 for Normal conditions ...
# Generating Coastal with Salmon diet 6 for Normal conditions ...
# Generating Coastal with Salmon diet 7 for Normal conditions ...
# Generating Coastal with Salmon diet 8 for Normal conditions ...
# Generating Coastal with Salmon diet 9 for Normal conditions ...
# Generating Coastal with Salmon diet 10 for Normal conditions ...
# Generating Coastal with Salmon diet 11 for Normal conditions ...
# Generating Coastal with Salmon diet 12 for Normal conditions ...
# Generating Coastal with Salmon diet 13 for Normal conditions ...
# Generating Coastal with Salmon diet 14 for Normal conditions ...
# Generating Coastal with Salmon diet 15 for Normal conditions ...
# ...

# %% [markdown]
# Annotate this cell with information about your code

# %%
csv_file = ''
temp_df = pd.read_csv(output_dir/f'{csv_file}.csv')

# %%
exportpeakdata(simulation='Protein',loadfile=output_dir/"coastal protein 10k second draft.pkl", region='Coastal',exportname="coastal diet survey first draft.csv", targets=[45,54])
# Out:
# DataFrame before exporting:
#     Target THg                    Protein Type    THg
# 0           45             Coastal with Salmon  45.00  \
# 1           45             Coastal with Salmon  45.00
# 2           45             Coastal with Salmon  44.99
# 3           45             Coastal with Salmon  44.99
# 4           45             Coastal with Salmon  44.99
# 5           45  Coastal without Salmon (moose)  44.88
# 6           45  Coastal without Salmon (moose)  44.87
# 7           45  Coastal without Salmon (moose)  44.78
# 8           45  Coastal without Salmon (moose)  44.77
# 9           45  Coastal without Salmon (moose)  44.75
# 10          54             Coastal with Salmon  54.00
# 11          54             Coastal with Salmon  54.00
# 12          54             Coastal with Salmon  54.01
# 13          54             Coastal with Salmon  53.99
# 14          54             Coastal with Salmon  53.99
#
#                                                  Diet
# ...
